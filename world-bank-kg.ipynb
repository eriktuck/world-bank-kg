# %%
import requests
import json
import pandas as pd
import numpy as np
import ast

# %%
url = 'https://search.worldbank.org/api/v2/wds'
params = {
    'format': 'json',
    'display_title': '"sustainable development"',
    'rows': 20,
    'page':1
}

metadata_list = []

for i in range(1):
    response = requests.get(url, params=params)
    data = json.loads(response.content)
    for doc_id in data['documents']:
        metadata = data['documents'][doc_id]
        metadata_list.append(metadata)

    params['page'] += 1

df = pd.DataFrame(metadata_list)

# %%
df.head()
# Out:
#          id    last_modified_date  \
# 0  34458416  2025-02-20T00:00:00Z
# 1  34455728  2025-02-13T00:00:00Z
# 2  34451551  2025-01-30T00:00:00Z
# 3  34450050  2025-01-27T00:00:00Z
# 4  34449455  2025-02-14T00:00:00Z
#
#                                               admreg     admreg_key  \
# 0    Europe and Central Asia,Europe and Central Asia  119226,119226
# 1  Latin America & Caribbean,Latin America & Cari...  119228,119228
# 2    Europe and Central Asia,Europe and Central Asia  119226,119226
# 3  Latin America & Caribbean,Latin America & Cari...  119228,119228
# 4                                                NaN            NaN
#
#                                       authors               count count_key  \
# 0              {'0': {'author': 'zgen alar'}}             Turkiye     82578
# 1     {'0': {'author': 'Siegmann,Katharina'}}  Dominican Republic     82640
# 2             {'0': {'author': 'Corsi,Anna'}}             Turkiye     82578
# 3  {'0': {'author': 'Paviot,Marie Caroline'}}              Brazil     82649
# 4             {'0': {'author': 'World Bank'}}            Honduras     82596
#
#                                                docna  \
# 0  {'0': {'docna': 'Turkiye - EUROPE AND CENTRAL ...
# 1  {'0': {'docna': 'Disclosable Version of the IS...
# 2  {'0': {'docna': 'Disclosable Version of the IS...
# 3  {'0': {'docna': 'Disclosable Restructuring Pap...
# 4  {'0': {'docna': 'Honduras - First Fiscal and C...
#
#                                       docty docty_key  ... available_in  \
# 0                          Procurement Plan    739941  ...      English
# 1  Implementation Status and Results Report    791001  ...      English
# 2  Implementation Status and Results Report    791001  ...      English
# 3                             Project Paper    810308  ...      English
# 4                          Program Document    640991  ...      English
#
#   fullavailablein                                                url  \
# 0              []  http://documents.worldbank.org/curated/en/0990...
# 1              []  http://documents.worldbank.org/curated/en/0990...
# 2              []  http://documents.worldbank.org/curated/en/0990...
# 3              []  http://documents.worldbank.org/curated/en/0990...
# 4              []  http://documents.worldbank.org/curated/en/0990...
#
#   EnvironmentalCategory                 bdmdt volnb               closedt  \
# 0                   NaN                   NaN   NaN                   NaN
# 1                   NaN                   NaN   NaN                   NaN
# 2                   NaN                   NaN   NaN                   NaN
# 3                     B                   NaN   NaN                   NaN
# 4                   NaN  2025-02-14T00:00:00Z     1  2025-02-14T00:00:00Z
#
#                                              topicv3 origu loan_no
# 0                                                NaN   NaN     NaN
# 1                                                NaN   NaN     NaN
# 2                                                NaN   NaN     NaN
# 3                                                NaN   NaN     NaN
# 4  Financial Integrity m1326313 328,Investment Cl...   NaN     NaN
#
# [5 rows x 58 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 58 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     20 non-null     object
#  1   last_modified_date     20 non-null     object
#  2   admreg                 19 non-null     object
#  3   admreg_key             19 non-null     object
#  4   authors                20 non-null     object
#  5   count                  20 non-null     object
#  6   count_key              20 non-null     object
#  7   docna                  20 non-null     object
#  8   docty                  20 non-null     object
#  9   docty_key              20 non-null     object
#  10  owner                  20 non-null     object
#  11  projn                  20 non-null     object
#  12  subsc                  13 non-null     object
#  13  trustfund              14 non-null     object
#  14  trustfund_key          14 non-null     object
#  15  theme                  13 non-null     object
#  16  prdln                  20 non-null     object
#  17  prdln_key              20 non-null     object
#  18  seccl                  20 non-null     object
#  19  lang                   20 non-null     object
#  20  lang_key               20 non-null     object
#  21  lndinstr               20 non-null     object
#  22  lndinstr_key           20 non-null     object
#  23  entityids              20 non-null     object
#  24  repnb                  16 non-null     object
#  25  docdt                  20 non-null     object
#  26  datestored             20 non-null     object
#  27  majdocty               20 non-null     object
#  28  majdocty_key           20 non-null     object
#  29  display_title          20 non-null     object
#  30  disclosure_date        20 non-null     object
#  31  disclosure_type        20 non-null     object
#  32  pdfurl                 20 non-null     object
#  33  txturl                 20 non-null     object
#  34  listing_relative_url   20 non-null     object
#  35  url_friendly_title     20 non-null     object
#  36  new_url                20 non-null     object
#  37  ext_pub_date           20 non-null     object
#  38  disclstat              20 non-null     object
#  39  docm_id                20 non-null     object
#  40  chronical_docm_id      20 non-null     object
#  41  publishtoextweb_dt     20 non-null     object
#  42  versiontyp             20 non-null     object
#  43  versiontyp_key         20 non-null     object
#  44  projectid              20 non-null     object
#  45  guid                   20 non-null     object
#  46  no_of_pages            20 non-null     object
#  47  author_keys            20 non-null     object
#  48  available_in           20 non-null     object
#  49  fullavailablein        20 non-null     object
#  50  url                    20 non-null     object
#  51  EnvironmentalCategory  5 non-null      object
#  52  bdmdt                  1 non-null      object
#  53  volnb                  1 non-null      object
#  54  closedt                1 non-null      object
#  55  topicv3                1 non-null      object
#  56  origu                  5 non-null      object
#  57  loan_no                1 non-null      object
# dtypes: object(58)
# memory usage: 9.6+ KB

# %%
import unidecode

def sanitize_column(series: pd.Series) -> pd.Series:
    """Clean strings for use in RDF identifiers (URIs or keys)."""
    return (series.astype(str)
                  .map(unidecode.unidecode) # remove accents
                  .str.replace(r'\s+', '_', regex=True) # replace spaces
                  .str.replace("-", "_") # replace hyphens
                  .str.strip("_")  # remove trailing underscore
                  .replace('nan', np.nan)  # return nan
    )

columns_to_sanitize = ['docty', 'count', 'trustfund', 'trustfund_key',
                       'projn', 'projectid']
df[columns_to_sanitize] = df[columns_to_sanitize].apply(sanitize_column)

# %%
df.to_csv("raw.csv")

# %%
from rdflib import Graph, RDF, RDFS, Namespace, URIRef, Literal
from rdflib.namespace import SKOS, XSD
from SPARQLWrapper import SPARQLWrapper, JSON
from tqdm import tqdm

# Set up RDF graph
g = Graph()
schema = Namespace("http://schema.org/")
wd = Namespace('http://www.wikidata.org/entity/')
ex = Namespace("http://worldbank.example.org/")

# Bind prefixes
prefixes = {
    'schema': schema,
    'wd': wd,
    'ex': ex,
    'skos': SKOS,
    'xsd': XSD
}
for p, ns in prefixes.items():
    g.bind(p, ns)

# %%
# Set up SPARQL connection
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setReturnFormat(JSON)
sparql.addCustomHttpHeader("User-Agent", "WorldBankKGBot/1.0 (eriktuck@gmail.com)")

# %% [markdown]
# ### Countries

# %%
countries = df['count'].dropna().unique()
countries
# Out:
# array(['Turkiye', 'Dominican_Republic', 'Brazil', 'Honduras', 'Argentina',
#        'India'], dtype=object)

# %%
def add_country_to_graph(qid_uri: str, country_code: str, label: str):
    """Adds a country instance to the RDF graph."""
    local_uri = ex[country_code]
    wikidata_uri = URIRef(qid_uri)

    g.add((local_uri, RDF.type, schema.Country))
    g.add((local_uri, schema.name, Literal(label, lang='en')))
    g.add((local_uri, schema.sameAs, wikidata_uri))


def query_via_sparql(query: str) -> str:
    """Runs any SPARQL query."""
    sparql.setQuery(query)
    results = sparql.query().convert()
    bindings = results['results']['bindings']
    if bindings:
        first_binding = bindings[0]
        # Get the first variable name from the binding
        var_name = next(iter(first_binding))
        return first_binding[var_name]['value']
    return None


def query_via_fuzzy_search(label: str) -> str:
    """Tries to find the QID via the Wikidata search API (fuzzy match)."""
    search_url = "https://www.wikidata.org/w/api.php"
    params = {
        "action": "wbsearchentities",
        "search": label,
        "language": "en",
        "format": "json",
        "type": "item"
    }
    response = requests.get(search_url, params=params)
    response.raise_for_status()
    search_results = response.json()

    if search_results['search']:
        qid = search_results['search'][0]['id']
        return f"http://www.wikidata.org/entity/{qid}"
    return None


# Main loop
for country in tqdm(countries):
    if not isinstance(country, str):
        continue

    label = country.replace('_', ' ')
    query = f"""
        SELECT ?country WHERE {{
            # ?country wdt:P31 wd:Q6256 .
            # ?country (rdfs:label|skos:altLabel) "{label}"@en .
        }}
        LIMIT 1
    """

    try:
        qid_uri = query_via_sparql(query)
        if qid_uri:
            add_country_to_graph(qid_uri, country, label)
        else:
            print(f"No exact match for: {label}. Trying fuzzy search...")
            try:
                qid_uri = query_via_fuzzy_search(label)
                if qid_uri:
                    add_country_to_graph(qid_uri, country, label)
                    print(f"Fuzzy match found: {label} → {qid_uri.split('/')[-1]}")
                else:
                    print(f"No fuzzy match found for: {label}")
            except Exception as fuzzy_error:
                print(f"Fuzzy search failed for {label}: {fuzzy_error}")
    except Exception as e:
        print(f"SPARQL query failed for {label}: {e}")
# Out:
#  17%|█▋        | 1/6 [00:00<00:01,  3.36it/s]
# No exact match for: Turkiye. Trying fuzzy search...
# Fuzzy match found: Turkiye → Q43
# 100%|██████████| 6/6 [00:00<00:00,  7.49it/s]

# %%
from collections import defaultdict

triples_by_subject = defaultdict(list)

for s, p, o in g:
    triples_by_subject[s].append((p, o))

for subject, po_list in triples_by_subject.items():
    print(f"\n🔹 {subject}")
    for predicate, obj in po_list:
        print(f"  ↳ {predicate} → {obj}")
# Out:
# 🔹 http://worldbank.example.org/Dominican_Republic
#   ↳ http://www.w3.org/1999/02/22-rdf-syntax-ns#type → http://schema.org/Country
#   ↳ http://schema.org/sameAs → http://www.wikidata.org/entity/Q786
#   ↳ http://schema.org/name → Dominican Republic
#
# 🔹 http://worldbank.example.org/Honduras
#   ↳ http://schema.org/name → Honduras
#   ↳ http://schema.org/sameAs → http://www.wikidata.org/entity/Q783
#   ↳ http://www.w3.org/1999/02/22-rdf-syntax-ns#type → http://schema.org/Country
#
# 🔹 http://worldbank.example.org/India
#   ↳ http://www.w3.org/1999/02/22-rdf-syntax-ns#type → http://schema.org/Country
#   ↳ http://schema.org/name → India
#   ↳ http://schema.org/sameAs → http://www.wikidata.org/entity/Q668
#
# 🔹 http://worldbank.example.org/Brazil
#   ↳ http://schema.org/name → Brazil
#   ↳ http://schema.org/sameAs → http://www.wikidata.org/entity/Q155
#   ↳ http://www.w3.org/1999/02/22-rdf-syntax-ns#type → http://schema.org/Country
#
# 🔹 http://worldbank.example.org/Turkiye
#   ↳ http://schema.org/name → Turkiye
#   ↳ http://schema.org/sameAs → http://www.wikidata.org/entity/Q43
#   ↳ http://www.w3.org/1999/02/22-rdf-syntax-ns#type → http://schema.org/Country
#
# 🔹 http://worldbank.example.org/Argentina
#   ↳ http://www.w3.org/1999/02/22-rdf-syntax-ns#type → http://schema.org/Country
#   ↳ http://schema.org/name → Argentina
#   ↳ http://schema.org/sameAs → http://www.wikidata.org/entity/Q414

# %%
from rdflib.extras.external_graph_libs import rdflib_to_networkx_graph
import matplotlib.pyplot as plt
import networkx as nx

nx_graph = rdflib_to_networkx_graph(g)

plt.figure(figsize=(12, 10))
nx.draw(
    nx_graph,
    with_labels=True,
    node_size=1500,
    node_color="lightblue",
    font_size=8,
    font_weight="bold",
    arrows=True
)
plt.title("Knowledge Graph Visualization")
plt.show()

# %%
from rdflib.tools.rdf2dot import rdf2dot
import io
import pydot

stream = io.StringIO()
rdf2dot(g, stream)
(graph,) = pydot.graph_from_dot_data(stream.getvalue())

# Save to file
graph.write_png("kg_diagram.png")  # or .svg, .pdf

# %%
import json
import os

CACHE_FILE = "wikidata_cache.json"

# Load cache if it exists
if os.path.exists(CACHE_FILE):
    with open(CACHE_FILE, "r") as f:
        cache = json.load(f)
else:
    cache = {
        "countries": {},
        "entities": {}
    }

# %%
# Properties to add
PROPERTY_MAP = {
    "continent": "P30",
    "form_of_government": "P122",
    "political_system": "P1387",
    "currency": "P38",
    "official_language": "P37",
    "population": "P1082",
    "gdp_per_capita": "P2299"
}

def enrich_country_qid(qid: str, country_uri: URIRef, properties: dict):
    """
    Enriches a country node in the RDF graph with contextual properties from Wikidata.

    Caches enrichment data and reuses the cached triples to avoid redundant queries.

    Parameters:
        qid (str): The Wikidata QID of the country (e.g., "Q43" for Turkey).
        country_uri (rdflib.term.URIRef): The URI of the country node in the local knowledge graph.
        properties (dict): A dictionary like {'property': 'pid'}

    Side Effects:
        - Adds new triples to the global RDF graph `g`.
        - Updates the global cache `cache` with newly retrieved triples.

    Raises:
        Prints an error message if the SPARQL query fails or returns unexpected results.
    """
    if qid in cache["countries"]:
        for triple in cache[qid]:
            subj = country_uri
            pred = URIRef(triple["predicate"])
            obj = URIRef(triple["object"]) if triple["type"] == "uri" else Literal(triple["object"])
            g.add((subj, pred, obj))
        return
    
    query = f"""
    SELECT ?property ?value ?valueLabel WHERE {{
        VALUES ?property {{ { ' '.join(f'wdt:{pid}' for pid in PROPERTY_MAP.values()) } }}
        wd:{qid} ?property ?value .
        SERVICE wikibase:label {{ bd:serviceParam wikibase:language "en". }}
    }}
    """
    try:
        sparql.setQuery(query)
        results = sparql.query().convert()
        cache_triples = []

        for result in results['results']['bindings']:
            prop_uri = result['property']['value']
            value = result['value']['value']
            label = result.get('valueLabel', {}).get('value', None)
            pred = URIRef(prop_uri)

            # Use wikidata URI if object is an entity
            if value.startswith("http://www.wikidata.org/entity"):
                obj = URIRef(value)
                obj_type = "uri"
            
                # Check if we've already added a label for this URIRef
                if value not in cache["entities"]:
                    if label:
                        g.add((obj, schema.name, Literal(label, lang="en")))
                        cache["entities"][value] = label

            else:
                obj = Literal(value)
                obj_type = "literal"
            
            g.add((country_uri, pred, obj))
            cache_triples.append({
                "predicate": str(prop_uri),
                "object": str(value),
                "type": obj_type
            })
            
        # Save to cache
        cache["countries"][qid] = cache_triples
            
    except Exception as e:
        print(f"Error enriching {qid}: {e}")

# Main loop
for country_uri in g.subjects(RDF.type, schema.Country):
    # Look for schema:sameAs link to Wikidata
    qid_uri = next(g.objects(country_uri, schema.sameAs), None)

    if qid_uri and "wikidata.org/entity/" in str(qid_uri):
        # Extract the QID from the URI
        qid = str(qid_uri).split("/")[-1]
        enrich_country_qid(qid, country_uri, PROPERTY_MAP)
    else:
        print(f"No Wikidata QID found for {country_uri}, skipping...")

# Write cache to file
with open(CACHE_FILE, "w") as f:
    json.dump(cache, f, indent=2)

# %%
# Set your target country
country_uri = ex["Turkiye"]

PID_TO_LABEL = {v: k.replace('_', ' ') for k, v in PROPERTY_MAP.items()}

# Extract all triples where Turkiye is subject
triples = list(g.triples((country_uri, None, None)))

# Add schema:name triples for URIRefs
for _, _, obj in triples:
    if isinstance(obj, URIRef):
        label = g.value(subject=obj, predicate=schema.name)
        if label:
            triples.append((obj, schema.name, label))

# Helper: get node label
def get_node_label(n):
    if isinstance(n, Literal):
        return str(n)
    label = g.value(subject=n, predicate=schema.name)
    if label:
        return str(label)
    return n.split("/")[-1]

# Helper: map P-code to readable label
def get_predicate_label(p):
    if isinstance(p, URIRef):
        pid = p.split("/")[-1]
        return PID_TO_LABEL.get(pid, pid)
    return get_node_label(p)

# Build the graph manually
G = nx.DiGraph()
for s, p, o in triples:
    s_label = get_node_label(s)
    o_label = get_node_label(o)
    p_label = get_predicate_label(p)

    G.add_node(s_label)
    G.add_node(o_label)
    G.add_edge(s_label, o_label, label=p_label)

# Draw it
plt.figure(figsize=(14, 10))
pos = nx.spring_layout(G, seed=42, k=1.2)

nx.draw(G, pos, with_labels=True,
        node_size=2000,
        node_color="lightblue",
        font_size=10,
        arrows=True)

# Add edge labels
edge_labels = {(u, v): d["label"] for u, v, d in G.edges(data=True)}
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=9)

plt.title("Knowledge Graph: ex:Turkiye", fontsize=14)
plt.axis("off")
plt.show()

# %%
df['trustfund'].unique()
# Out:
# array(['TF0C4083_Leveraging_property_and_geospatial_data_for_disaster_and_climate_resili,TF0C5286_T00fcrkiye:_Leveraging_National_Spatial_Data_Infrastructure_for_Smart_C,TF0C6078_GSCP___C2___Turkiye:_Geospatial_informed_Smart_City_Strategies_for_Publ',
#        'TF0C5780_Technical_Assistance_for_Establishing_Science_Based_Policy_Options_for,TF0C5873_Investing_in_the_Dominican_Republics_Green_Recovery_and_Blue_Economy',
#        nan,
#        'TF098374_Supporting_the_Implementation_of_Phase_1_of_the_Matanza_Riachuelo_Basin,TF0B8604_Circular_Economy_Actions_for_Non_Point_Source_Pollution_Reduction_at_th,TF0B9831_Circular_Economy_for_Waste_Management_in_Province_of_Buenos_Aires',
#        'TF0C4697_Haryana_Clean_Air_Project_for_Sustainable_Development:_Clean_Cooking_Pr',
#        'TF0C5871_CH4D___Brazil___Methane_Action_in_Livestock_Practices',
#        'TF0B8604_Circular_Economy_Actions_for_Non_Point_Source_Pollution_Reduction_at_th,TF0B9831_Circular_Economy_for_Waste_Management_in_Province_of_Buenos_Aires,TF098374_Supporting_the_Implementation_of_Phase_1_of_the_Matanza_Riachuelo_Basin'],
#       dtype=object)

# %%
def get_entity_label(entity_code:int):
    """
    Get an entity label given an entity code from Wikidata
    UNUSED
    """

    # Construct the SPARQL query
    query = f"""
        SELECT ?label WHERE {{
            wd:{entity_code} rdfs:label ?label.
            FILTER (lang(?label) = 'en)
        }}
    """

    # Set the query and response format
    sparql.setQuery(query)

    # Execute the query and retrieve results
    results = sparql.query().convert()

    # Extract and return the entity label
    if ('results' in results and 
        'bindings' in results['results'] and
        results['results']['bindings']):
        label = results['results']['bindings'][0]['label']['value']
        return label
    
    return None

# %%
def create_subclass_country(column:str):
    """
    Create the country subclass and add to graph.
    Note some entries are regions or continents.
    """
    newClass = URIRef(schema + "country")
    g.add((newClass, RDFS.label, Literal("country", lang='en')))
    
    for value in df[column].unique():
        if value != "nan":
            # Check Wikidata for a matching class
            query = f"""
              SELECT ?class ?label WHERE {{
                # ?class wdt:P31 wd:Q6256 .
                # ?class rdfs:label "{value}"@en .
                OPTIONAL {{ ?class skos:prefLabel ?label FILTER(lang(?label) = "en")}}
                FILTER(REGEX(STR(?class), "^http://www.wikidata.org/entity/Q[0-9]+$"))
              }}
            """

            # Set the query and response format
            sparql.setQuery(query)
            results = sparql.query().convert()

            # If there is a match, use the Wikidata class as a subclass
            if results['results']['bindings']:
                
                # Get URI from Wikidata
                uri = results['results']['bindings'][0]['class']['value']

                # Get the 'Q ID' which is the unique ID at the end of the URI
                qid = uri.split('/'[-1])
                country_label = value

                # Create a subclass for each country under the country class
                subclass = URIRef(schema + country_label.replace(' ', '_'))
                g.add((subclass, RDF.type, RDFS.Class))
                g.add((subclass, RDFS.subClassOf, newClass))

                # Update the "country_URI" column with the URI for the current country
                df.loc[df[column] == value, "country_URI"] = uri
                uri = URIRef(uri)

                # Define the URI for the new Wikidata URI property
                wd_URI_property = URIRef(schema + "wd_RUI")

                # Add the property to the RDF graph
                g.add((wd_URI_property, RDF.type, RDF.Property))

                # Add a label to the property
                label = Literal("Wikidata URI", lang="en")
                g.add((subclass, schema.wd_RUI, uri))

                # Add albel to each Wididata Q ID code that 
                # it is the Q ID for this particular country
                g.add((uri, RDFS.label, Literal(f"{country_label} wikidata code", lang="en")))
                g.add((subclass, RDFS.label, Literal(value, lang='en')))

            else:
                subclass = URIRef(schema + value.replace(' ', '_').replace('-', '_'))
                g.add((subclass, RDF.type, RDFS.Class))
                g.add((subclass, RDFS.subClassOf, newClass))
                g.add((subclass, RDFS.label, Literal(value, lang='en')))

# %%
def create_subclass_world_bank_document(column:str):
    newClass = URIRef(schema + "world_bank_document")
    g.add((newClass, RDFS.label, Literal("A document produced and written by the World Bank.", lang='en')))   

    for value in df[column].unique():
        if isinstance(value, str):
            # Check Wikidata for a matching class
            query = f"""
                SELECT ?class ?label WHERE {{
                    # ?class rdfs:label "{value}"@en .
                    OPTIONAL {{ ?class skos:prefLabel ?label FILTER(lang(?label) = "en") }}
                    FILTER(REGEX(STR(?class), "^http://www.wikidata.org/entity/Q[0-9]+$"))
                }}
            """
            
            sparql.setQuery(query)
            results = sparql.query().convert()
            
            if value != "nan":
                # If there is a match, use the Wikidata class as a subclass
                if results['results']['bindings']:
                    wd_class = results['results']['bindings'][0]['class']['value']
                    # qid = wd_class.split('/')[-1]
                    label = value
                    subclass = URIRef(schema + label.replace(' ', '_'))
                    g.add((subclass, RDF.type, RDFS.Class))
                    g.add((subclass, RDFS.subClassOf, newClass))

                    wd_uri = URIRef(wd_class)

                    # Define the URI for the new property
                    wd_URI_property = URIRef(schema + "wd_URI")

                    # Add the property to the RDF graph
                    g.add((wd_URI_property, RDF.type, RDF.Property))

                    # Add a label to the property
                    label = Literal("Wikidata URI", lang="en")
                    g.add((wd_URI_property, RDFS.label, label))

                    g.add((subclass, schema.wd_URI, wd_uri))
                    g.add((wd_uri, RDFS.label, Literal("entity wikidata code", lang='en')))
                    g.add((subclass, RDFS.label, Literal(value, lang='en')))
                    df[column] = df[column].replace(value, str(subclass))

                else:
                    subclass = URIRef(schema + value.replace(' ', '_').replace('-','_'))
                    g.add((subclass, RDF.type, RDFS.Class))
                    g.add((subclass, RDFS.subClassOf, newClass))
                    g.add((subclass, RDFS.label, Literal(value, lang='en')))
                    df[column] = df[column].replace(value, str(subclass))

# %%
def create_subclass_trustfund(column, ids=None):
    newClass = URIRef(schema + "trustfund")
    g.add((newClass, RDFS.label, Literal("trustfund")))

    # Define the id property
    id_property = schema.identifier
    g.add((id_property, RDF.type, RDF.Property))
    g.add((id_property, RDFS.label, Literal("Identifier")))

    # Associate the id property with the trustfund class
    g.add((id_property, RDFS.domain, newClass))

    for rowValue in df[column].unique():
        if rowValue != "nan":
            names = rowValue.split(",")
            if ids is not None:
                for name in names:
                    newID = URIRef(schema + "trustfund" + "/" + str(name))
                    g.add((newID, RDF.type, newClass))
                    g.add((newID, RDFS.label, Literal(str(name))))
                    if name in ids:
                        id = ids[name]
                        # Create a URIRef for the trustfund_id resource
                        trustfund_id = URIRef(schema + "trustfund" + "/id/" + Literal(id, datatype=XSD.string))
                        g.add((newID, id_property, trustfund_id))
                        label = Literal(f"world bank trustfund ID for {name}", lang="en")
                        g.add((trustfund_id, RDFS.label, label))

# %%
def create_subclass_project(column):
    newClass = URIRef(schema + "project")
    g.add((newClass, RDFS.label, Literal("worldbank project")))

    for value in df[column].unique():
        if value != "nan":
            newID = URIRef(schema + "project/" + str(value).replace(" ","_").replace("-","_"))
            g.add((newID, RDF.type, newClass))
            g.add((newID, RDFS.label, Literal(str(value).replace(" ","_").replace("-","_"), lang='en')))

# %%
def create_subclass_authors(column):
    newClass = URIRef(schema + str(column))
    g.add((newClass, RDFS.label, Literal("worldbank authors")))

    for value in df[column].unique():
        if value != "nan":
            # Add author property for each author
            author_dict = ast.literal_eval(value)
            for author_dict_entries in author_dict.values():
                author_name = author_dict_entries['author']
                author_uri = URIRef(schema + "author/" + author_name.replace(" ", "_"))
                g.add((author_uri, RDF.type, newClass))
                g.add((author_uri, RDFS.label, Literal(author_name, lang='en')))

# %%
# Create a dictionary that maps trustfund keys to trustfund names
trustfund_dict = {}
for i, row in df.iterrows():
    keys = row['trustfund'].split(',')
    values = row['trustfund_key'].split(',')
    for key, value in zip(keys, values):
        trustfund_dict[key.strip()] = value.strip()

trustfund_dict
# Out:
# {'TF0C4083_Leveraging_property_and_geospatial_data_for_disaster_and_climate_resili': '2396084',
#  'TF0C5286_T00fcrkiye:_Leveraging_National_Spatial_Data_Infrastructure_for_Smart_C': '2442455',
#  'TF0C6078_GSCP___C2___Turkiye:_Geospatial_informed_Smart_City_Strategies_for_Publ': '2463445',
#  'TF0C5780_Technical_Assistance_for_Establishing_Science_Based_Policy_Options_for': '2458413',
#  'TF0C5873_Investing_in_the_Dominican_Republics_Green_Recovery_and_Blue_Economy': '2458505',
#  'nan': 'nan',
#  'TF098374_Supporting_the_Implementation_of_Phase_1_of_the_Matanza_Riachuelo_Basin': '1136287',
#  'TF0B8604_Circular_Economy_Actions_for_Non_Point_Source_Pollution_Reduction_at_th': '2169235',
#  'TF0B9831_Circular_Economy_for_Waste_Management_in_Province_of_Buenos_Aires': '2230395',
#  'TF0C4697_Haryana_Clean_Air_Project_for_Sustainable_Development:_Clean_Cooking_Pr': '2416574',
#  'TF0C5871_CH4D___Brazil___Methane_Action_in_Livestock_Practices': '2458503'}

# %%
# Create a dictionary that maps project keys to project names
project_dict = {}
for i, row in df.iterrows():
    keys = row['projectid'].split(',')
    values = row['projn'].split(',')
    for key, value in zip(keys, values):
        project_dict[key.strip()] = value.strip()

project_dict
# Out:
# {'P179217': 'TR_Land_Management_Infrastructure_For_Green_And_Sustainable_Develo____P179217',
#  'P500557': 'DO_Sustainable_Development_Dpl____P500557',
#  'P167455': 'BR_Ceara_Rural_Sustainable_Development_And_Competitiveness_Phase_I____P167455',
#  'P179909': 'HN_First_Fiscal_And_Climate_Transparency_And_Sustainability_Develo____P179909',
#  'P105680': 'AR_Matanza_Riachuelo_Basin_Sustainable_Development_Project____P105680',
#  'P502491': 'IN_Haryana_Clean_Air_And_Sustainable_Development_Program_P502491',
#  'P175723': 'BR_Mato_Grosso_Sustainable_Development_Of_Family_Farming____P175723',
#  'nan': 'nan'}

# %%
create_subclass_country('count')
create_subclass_world_bank_document('docty')
create_subclass_trustfund('trustfund', trustfund_dict)
create_subclass_project('projn')
create_subclass_authors('authors')

# %%
g.serialize('world-bank-kg.ttl', format='turtle', prefixes=prefixes, encoding='utf-8')
g.serialize("world-bank-kg.nt", format="nt", prefixes=prefixes, encoding='urf-8')
# Out:
# /home/erikt/_dev/world-bank-kg/.venv/lib/python3.12/site-packages/rdflib/plugins/serializers/nt.py:41: UserWarning: NTSerializer always uses UTF-8 encoding. Given encoding was: urf-8
#   warnings.warn(
# <Graph identifier=N09d496b900c14db6ba9b6254a1965296 (<class 'rdflib.graph.Graph'>)>

# %%
for subject, predicate, object in g:
    print(f"{subject} {predicate} {object}")
# Out:
# http://schema.org/identifier http://www.w3.org/2000/01/rdf-schema#domain http://schema.org/trustfund
# http://www.wikidata.org/entity/Q783 http://www.w3.org/2000/01/rdf-schema#label Honduras wikidata code
# http://schema.org/project/AR_Matanza_Riachuelo_Basin_Sustainable_Development_Project____P105680 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/project
# http://schema.org/Environmental_and_Social_Commitment_Plan http://www.w3.org/2000/01/rdf-schema#subClassOf http://schema.org/world_bank_document
# http://schema.org/trustfund/TF0C4697_Haryana_Clean_Air_Project_for_Sustainable_Development:_Clean_Cooking_Pr http://schema.org/identifier http://schema.org/trustfund/id/2416574
# http://schema.org/Environmental_and_Social_Review_Summary http://www.w3.org/2000/01/rdf-schema#subClassOf http://schema.org/world_bank_document
# http://schema.org/trustfund/id/2458505 http://www.w3.org/2000/01/rdf-schema#label world bank trustfund ID for TF0C5873_Investing_in_the_Dominican_Republics_Green_Recovery_and_Blue_Economy
# http://schema.org/author/zgen_alar http://www.w3.org/2000/01/rdf-schema#label zgen alar
# http://schema.org/trustfund/id/2463445 http://www.w3.org/2000/01/rdf-schema#label world bank trustfund ID for TF0C6078_GSCP___C2___Turkiye:_Geospatial_informed_Smart_City_Strategies_for_Publ
# http://schema.org/author/Lucas_Figueras http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/authors
# http://schema.org/author/Lafaete_Almeida_de_Oliveira http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/authors
# http://schema.org/Procurement_Plan http://www.w3.org/2000/01/rdf-schema#subClassOf http://schema.org/world_bank_document
# http://schema.org/Dominican_Republic http://www.w3.org/2000/01/rdf-schema#subClassOf http://schema.org/country
# http://schema.org/trustfund/TF0C4083_Leveraging_property_and_geospatial_data_for_disaster_and_climate_resili http://www.w3.org/2000/01/rdf-schema#label TF0C4083_Leveraging_property_and_geospatial_data_for_disaster_and_climate_resili
# http://schema.org/trustfund/TF0C5286_T00fcrkiye:_Leveraging_National_Spatial_Data_Infrastructure_for_Smart_C http://schema.org/identifier http://schema.org/trustfund/id/2442455
# http://schema.org/trustfund/id/2458503 http://www.w3.org/2000/01/rdf-schema#label world bank trustfund ID for TF0C5871_CH4D___Brazil___Methane_Action_in_Livestock_Practices
# http://schema.org/Honduras http://schema.org/wd_RUI http://www.wikidata.org/entity/Q783
# http://schema.org/Environmental_and_Social_Review_Summary http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://schema.org/author/Lucas_Figueras http://www.w3.org/2000/01/rdf-schema#label Lucas Figueras
# http://schema.org/author/Borrowing_Agency http://www.w3.org/2000/01/rdf-schema#label Borrowing Agency
# http://schema.org/Project_Paper http://www.w3.org/2000/01/rdf-schema#label Project_Paper
# http://www.wikidata.org/entity/Q414 http://www.w3.org/2000/01/rdf-schema#label Argentina wikidata code
# http://schema.org/trustfund/TF098374_Supporting_the_Implementation_of_Phase_1_of_the_Matanza_Riachuelo_Basin http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/trustfund
# http://schema.org/trustfund/TF0B8604_Circular_Economy_Actions_for_Non_Point_Source_Pollution_Reduction_at_th http://schema.org/identifier http://schema.org/trustfund/id/2169235
# http://schema.org/Project_Paper http://www.w3.org/2000/01/rdf-schema#subClassOf http://schema.org/world_bank_document
# http://schema.org/trustfund/TF0C5873_Investing_in_the_Dominican_Republics_Green_Recovery_and_Blue_Economy http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/trustfund
# http://schema.org/author/Noronha_Farinelli,Barbara_Cristina http://www.w3.org/2000/01/rdf-schema#label Noronha Farinelli,Barbara Cristina
# http://schema.org/trustfund/TF0B9831_Circular_Economy_for_Waste_Management_in_Province_of_Buenos_Aires http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/trustfund
# http://schema.org/project/BR_Ceara_Rural_Sustainable_Development_And_Competitiveness_Phase_I____P167455 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/project
# http://schema.org/Honduras http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://schema.org/trustfund/TF0C6078_GSCP___C2___Turkiye:_Geospatial_informed_Smart_City_Strategies_for_Publ http://schema.org/identifier http://schema.org/trustfund/id/2463445
# http://schema.org/trustfund/TF0C4697_Haryana_Clean_Air_Project_for_Sustainable_Development:_Clean_Cooking_Pr http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/trustfund
# http://schema.org/Program_Document http://www.w3.org/2000/01/rdf-schema#label Program_Document
# http://schema.org/Procurement_Plan http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://schema.org/Honduras http://www.w3.org/2000/01/rdf-schema#subClassOf http://schema.org/country
# http://schema.org/Project_Paper http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://schema.org/author/Borrowing_Agency http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/authors
# http://schema.org/Program_Document http://www.w3.org/2000/01/rdf-schema#subClassOf http://schema.org/world_bank_document
# http://schema.org/identifier http://www.w3.org/2000/01/rdf-schema#label Identifier
# http://schema.org/trustfund/TF0B9831_Circular_Economy_for_Waste_Management_in_Province_of_Buenos_Aires http://schema.org/identifier http://schema.org/trustfund/id/2230395
# http://schema.org/project/TR_Land_Management_Infrastructure_For_Green_And_Sustainable_Develo____P179217 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/project
# http://schema.org/trustfund/TF0C5873_Investing_in_the_Dominican_Republics_Green_Recovery_and_Blue_Economy http://www.w3.org/2000/01/rdf-schema#label TF0C5873_Investing_in_the_Dominican_Republics_Green_Recovery_and_Blue_Economy
# http://schema.org/trustfund/TF0B8604_Circular_Economy_Actions_for_Non_Point_Source_Pollution_Reduction_at_th http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/trustfund
# http://schema.org/author/Paviot,Marie_Caroline http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/authors
# http://schema.org/identifier http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://schema.org/trustfund/id/2416574 http://www.w3.org/2000/01/rdf-schema#label world bank trustfund ID for TF0C4697_Haryana_Clean_Air_Project_for_Sustainable_Development:_Clean_Cooking_Pr
# http://schema.org/Honduras http://www.w3.org/2000/01/rdf-schema#label Honduras
# http://schema.org/Brazil http://schema.org/wd_RUI http://www.wikidata.org/entity/Q155
# http://schema.org/trustfund http://www.w3.org/2000/01/rdf-schema#label trustfund
# http://schema.org/author/World_Bank http://www.w3.org/2000/01/rdf-schema#label World Bank
# http://schema.org/Implementation_Status_and_Results_Report http://www.w3.org/2000/01/rdf-schema#label Implementation_Status_and_Results_Report
# http://schema.org/project/TR_Land_Management_Infrastructure_For_Green_And_Sustainable_Develo____P179217 http://www.w3.org/2000/01/rdf-schema#label TR_Land_Management_Infrastructure_For_Green_And_Sustainable_Develo____P179217
# http://schema.org/trustfund/TF0C5286_T00fcrkiye:_Leveraging_National_Spatial_Data_Infrastructure_for_Smart_C http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/trustfund
# http://schema.org/Turkiye http://www.w3.org/2000/01/rdf-schema#label Turkiye
# http://schema.org/Program_Document http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://schema.org/project/BR_Mato_Grosso_Sustainable_Development_Of_Family_Farming____P175723 http://www.w3.org/2000/01/rdf-schema#label BR_Mato_Grosso_Sustainable_Development_Of_Family_Farming____P175723
# http://schema.org/trustfund/TF0C5780_Technical_Assistance_for_Establishing_Science_Based_Policy_Options_for http://schema.org/identifier http://schema.org/trustfund/id/2458413
# http://schema.org/Dominican_Republic http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://schema.org/Implementation_Status_and_Results_Report http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://schema.org/author/Ramirez,Maria_Catalina http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/authors
# http://schema.org/author/Noronha_Farinelli,Barbara_Cristina http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/authors
# http://schema.org/trustfund/TF0C6078_GSCP___C2___Turkiye:_Geospatial_informed_Smart_City_Strategies_for_Publ http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/trustfund
# http://schema.org/project/DO_Sustainable_Development_Dpl____P500557 http://www.w3.org/2000/01/rdf-schema#label DO_Sustainable_Development_Dpl____P500557
# http://schema.org/author/Ramirez,Maria_Catalina http://www.w3.org/2000/01/rdf-schema#label Ramirez,Maria Catalina
# http://schema.org/author/Chichgar,Sharlene_Jehanbux http://www.w3.org/2000/01/rdf-schema#label Chichgar,Sharlene Jehanbux
# http://schema.org/project/HN_First_Fiscal_And_Climate_Transparency_And_Sustainability_Develo____P179909 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/project
# http://schema.org/Environmental_and_Social_Review_Summary http://www.w3.org/2000/01/rdf-schema#label Environmental_and_Social_Review_Summary
# http://schema.org/trustfund/TF0C4083_Leveraging_property_and_geospatial_data_for_disaster_and_climate_resili http://schema.org/identifier http://schema.org/trustfund/id/2396084
# http://schema.org/project/BR_Ceara_Rural_Sustainable_Development_And_Competitiveness_Phase_I____P167455 http://www.w3.org/2000/01/rdf-schema#label BR_Ceara_Rural_Sustainable_Development_And_Competitiveness_Phase_I____P167455
# http://schema.org/project/HN_First_Fiscal_And_Climate_Transparency_And_Sustainability_Develo____P179909 http://www.w3.org/2000/01/rdf-schema#label HN_First_Fiscal_And_Climate_Transparency_And_Sustainability_Develo____P179909
# http://schema.org/author/Chichgar,Sharlene_Jehanbux http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/authors
# http://schema.org/country http://www.w3.org/2000/01/rdf-schema#label country
# http://schema.org/Stakeholder_Engagement_Plan http://www.w3.org/2000/01/rdf-schema#label Stakeholder_Engagement_Plan
# http://schema.org/Procurement_Plan http://www.w3.org/2000/01/rdf-schema#label Procurement_Plan
# http://schema.org/Stakeholder_Engagement_Plan http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://schema.org/trustfund/TF0C5871_CH4D___Brazil___Methane_Action_in_Livestock_Practices http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/trustfund
# http://schema.org/Argentina http://schema.org/wd_RUI http://www.wikidata.org/entity/Q414
# http://schema.org/trustfund/TF0C6078_GSCP___C2___Turkiye:_Geospatial_informed_Smart_City_Strategies_for_Publ http://www.w3.org/2000/01/rdf-schema#label TF0C6078_GSCP___C2___Turkiye:_Geospatial_informed_Smart_City_Strategies_for_Publ
# http://schema.org/Implementation_Status_and_Results_Report http://www.w3.org/2000/01/rdf-schema#subClassOf http://schema.org/world_bank_document
# http://schema.org/Brazil http://www.w3.org/2000/01/rdf-schema#label Brazil
# http://schema.org/India http://www.w3.org/2000/01/rdf-schema#label India
# http://schema.org/trustfund/TF0C5286_T00fcrkiye:_Leveraging_National_Spatial_Data_Infrastructure_for_Smart_C http://www.w3.org/2000/01/rdf-schema#label TF0C5286_T00fcrkiye:_Leveraging_National_Spatial_Data_Infrastructure_for_Smart_C
# http://schema.org/trustfund/TF0C5780_Technical_Assistance_for_Establishing_Science_Based_Policy_Options_for http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/trustfund
# http://schema.org/trustfund/TF0C4697_Haryana_Clean_Air_Project_for_Sustainable_Development:_Clean_Cooking_Pr http://www.w3.org/2000/01/rdf-schema#label TF0C4697_Haryana_Clean_Air_Project_for_Sustainable_Development:_Clean_Cooking_Pr
# http://schema.org/trustfund/TF0B8604_Circular_Economy_Actions_for_Non_Point_Source_Pollution_Reduction_at_th http://www.w3.org/2000/01/rdf-schema#label TF0B8604_Circular_Economy_Actions_for_Non_Point_Source_Pollution_Reduction_at_th
# http://schema.org/author/Corsi,Anna http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/authors
# http://schema.org/trustfund/TF0C4083_Leveraging_property_and_geospatial_data_for_disaster_and_climate_resili http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/trustfund
# http://schema.org/Turkiye http://www.w3.org/2000/01/rdf-schema#subClassOf http://schema.org/country
# http://schema.org/Argentina http://www.w3.org/2000/01/rdf-schema#label Argentina
# http://schema.org/trustfund/TF0C5780_Technical_Assistance_for_Establishing_Science_Based_Policy_Options_for http://www.w3.org/2000/01/rdf-schema#label TF0C5780_Technical_Assistance_for_Establishing_Science_Based_Policy_Options_for
# http://schema.org/project/DO_Sustainable_Development_Dpl____P500557 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/project
# http://schema.org/Brazil http://www.w3.org/2000/01/rdf-schema#subClassOf http://schema.org/country
# http://schema.org/Dominican_Republic http://schema.org/wd_RUI http://www.wikidata.org/entity/Q786
# http://schema.org/Brazil http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://schema.org/trustfund/id/2230395 http://www.w3.org/2000/01/rdf-schema#label world bank trustfund ID for TF0B9831_Circular_Economy_for_Waste_Management_in_Province_of_Buenos_Aires
# http://schema.org/world_bank_document http://www.w3.org/2000/01/rdf-schema#label A document produced and written by the World Bank.
# http://schema.org/author/Siegmann,Katharina http://www.w3.org/2000/01/rdf-schema#label Siegmann,Katharina
# http://schema.org/Environmental_and_Social_Commitment_Plan http://www.w3.org/2000/01/rdf-schema#label Environmental_and_Social_Commitment_Plan
# http://schema.org/author/Lafaete_Almeida_de_Oliveira http://www.w3.org/2000/01/rdf-schema#label Lafaete Almeida de Oliveira
# http://schema.org/author/World_Bank http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/authors
# http://schema.org/Program_for_Results_Environmental_and_Social_Systems_Assessment http://www.w3.org/2000/01/rdf-schema#subClassOf http://schema.org/world_bank_document
# http://schema.org/trustfund/id/2458413 http://www.w3.org/2000/01/rdf-schema#label world bank trustfund ID for TF0C5780_Technical_Assistance_for_Establishing_Science_Based_Policy_Options_for
# http://schema.org/trustfund/id/2396084 http://www.w3.org/2000/01/rdf-schema#label world bank trustfund ID for TF0C4083_Leveraging_property_and_geospatial_data_for_disaster_and_climate_resili
# http://schema.org/author/Maria_Salene_Maia_da_Silva http://www.w3.org/2000/01/rdf-schema#label Maria Salene Maia da Silva
# http://schema.org/project/IN_Haryana_Clean_Air_And_Sustainable_Development_Program_P502491 http://www.w3.org/2000/01/rdf-schema#label IN_Haryana_Clean_Air_And_Sustainable_Development_Program_P502491
# http://schema.org/trustfund/id/1136287 http://www.w3.org/2000/01/rdf-schema#label world bank trustfund ID for TF098374_Supporting_the_Implementation_of_Phase_1_of_the_Matanza_Riachuelo_Basin
# http://schema.org/India http://www.w3.org/2000/01/rdf-schema#subClassOf http://schema.org/country
# http://schema.org/trustfund/TF0C5873_Investing_in_the_Dominican_Republics_Green_Recovery_and_Blue_Economy http://schema.org/identifier http://schema.org/trustfund/id/2458505
# http://schema.org/trustfund/TF0B9831_Circular_Economy_for_Waste_Management_in_Province_of_Buenos_Aires http://www.w3.org/2000/01/rdf-schema#label TF0B9831_Circular_Economy_for_Waste_Management_in_Province_of_Buenos_Aires
# http://schema.org/project/IN_Haryana_Clean_Air_And_Sustainable_Development_Program_P502491 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/project
# http://schema.org/wd_RUI http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://schema.org/author/Corsi,Anna http://www.w3.org/2000/01/rdf-schema#label Corsi,Anna
# http://schema.org/Program_for_Results_Environmental_and_Social_Systems_Assessment http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://schema.org/India http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://schema.org/Dominican_Republic http://www.w3.org/2000/01/rdf-schema#label Dominican Republic
# http://schema.org/author/Maria_Salene_Maia_da_Silva http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/authors
# http://schema.org/project/BR_Mato_Grosso_Sustainable_Development_Of_Family_Farming____P175723 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/project
# http://schema.org/authors http://www.w3.org/2000/01/rdf-schema#label worldbank authors
# http://www.wikidata.org/entity/Q155 http://www.w3.org/2000/01/rdf-schema#label Brazil wikidata code
# http://schema.org/author/zgen_alar http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/authors
# http://schema.org/trustfund/TF098374_Supporting_the_Implementation_of_Phase_1_of_the_Matanza_Riachuelo_Basin http://www.w3.org/2000/01/rdf-schema#label TF098374_Supporting_the_Implementation_of_Phase_1_of_the_Matanza_Riachuelo_Basin
# http://schema.org/Turkiye http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://schema.org/Argentina http://www.w3.org/2000/01/rdf-schema#subClassOf http://schema.org/country
# http://schema.org/Environmental_and_Social_Commitment_Plan http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://schema.org/Argentina http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://schema.org/Stakeholder_Engagement_Plan http://www.w3.org/2000/01/rdf-schema#subClassOf http://schema.org/world_bank_document
# http://schema.org/project/AR_Matanza_Riachuelo_Basin_Sustainable_Development_Project____P105680 http://www.w3.org/2000/01/rdf-schema#label AR_Matanza_Riachuelo_Basin_Sustainable_Development_Project____P105680
# http://schema.org/trustfund/TF0C5871_CH4D___Brazil___Methane_Action_in_Livestock_Practices http://www.w3.org/2000/01/rdf-schema#label TF0C5871_CH4D___Brazil___Methane_Action_in_Livestock_Practices
# http://schema.org/India http://schema.org/wd_RUI http://www.wikidata.org/entity/Q668
# http://schema.org/trustfund/TF098374_Supporting_the_Implementation_of_Phase_1_of_the_Matanza_Riachuelo_Basin http://schema.org/identifier http://schema.org/trustfund/id/1136287
# http://schema.org/trustfund/id/2442455 http://www.w3.org/2000/01/rdf-schema#label world bank trustfund ID for TF0C5286_T00fcrkiye:_Leveraging_National_Spatial_Data_Infrastructure_for_Smart_C
# http://www.wikidata.org/entity/Q668 http://www.w3.org/2000/01/rdf-schema#label India wikidata code
# http://schema.org/Program_for_Results_Environmental_and_Social_Systems_Assessment http://www.w3.org/2000/01/rdf-schema#label Program_for_Results_Environmental_and_Social_Systems_Assessment
# http://schema.org/trustfund/TF0C5871_CH4D___Brazil___Methane_Action_in_Livestock_Practices http://schema.org/identifier http://schema.org/trustfund/id/2458503
# http://schema.org/author/Paviot,Marie_Caroline http://www.w3.org/2000/01/rdf-schema#label Paviot,Marie Caroline
# http://schema.org/project http://www.w3.org/2000/01/rdf-schema#label worldbank project
# http://www.wikidata.org/entity/Q786 http://www.w3.org/2000/01/rdf-schema#label Dominican Republic wikidata code
# http://schema.org/trustfund/id/2169235 http://www.w3.org/2000/01/rdf-schema#label world bank trustfund ID for TF0B8604_Circular_Economy_Actions_for_Non_Point_Source_Pollution_Reduction_at_th
# http://schema.org/author/Siegmann,Katharina http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://schema.org/authors

# %%
# Create author properties
authoredBy_uri = URIRef(schema + "authoredBy")
authored_uri = URIRef(schema + "authored")
g.add((authoredBy_uri, RDF.type, RDF.Property))
g.add((authored_uri, RDF.type, RDF.Property))
g.add((authoredBy_uri, RDFS.label, Literal("This document was authored by this author.")))
g.add((authored_uri, RDFS.label, Literal("This author wrote this document.")))

# Define 'part of' property
isPartOf_uri = URIRef(schema + "isPartOf")
g.add((isPartOf_uri, RDF.type, RDF.Property))
g.add((isPartOf_uri, RDFS.label, Literal("This entity is a part of another entity")))

# Define 'countryOfOrigin' property
countryOfOrigin_uri = URIRef(schema + "countryOfOrigin")
g.add((countryOfOrigin_uri, RDF.type, RDF.Property))
g.add((countryOfOrigin_uri, RDFS.label, Literal("Country that this document is about.")))

# Create instances for each document and add author property
for index, row in tqdm(df.iterrows()):
    if not pd.isnull(row['id']) and not pd.isnull(row['docty']) and not pd.isnull(row['authors']):
        try:
            # Create the report instance
            instance = URIRef(schema + "doc/" + str(row['display_title']).replace(" ","_").replace("-","_"))
            g.add((instance, RDFS.label, Literal(str(row['display_title']), lang='en')))
            
            #Connect instances with types of documents
            doctype = URIRef(row['docty'])
            g.add((instance, RDF.type, doctype))
    
            #Connect instances with country of origin
            if row['count'] != "nan":
                country = URIRef(schema + str(row['count']).replace(" ","_").replace("-","_"))
                g.add((instance, countryOfOrigin_uri, country))

            #Connect instances with projects
            if row['projn'] != "nan":
                project = URIRef(schema + "project/" + str(row['projn']).replace(" ","_").replace("-","_"))
                g.add((instance, isPartOf_uri, project))

            #Connect instances with trustfund_keys
            if row['trustfund'] != "nan":
                tf_values = row['trustfund'].split(",")
                for tf in tf_values:
                    trustfund_uri = URIRef(schema + "trustfund/" + str(tf).replace(" ","_").replace("-","_"))
                    g.add((trustfund_uri, RDFS.label, Literal(f"Trustfund: {tf}")))
                    g.add((instance, isPartOf_uri, trustfund_uri))
                    g.add((trustfund_uri, countryOfOrigin_uri, country))
                
            #Connect instances with authors
            author_dict = ast.literal_eval(row['authors'])
            for author_dict_entries in author_dict.values():
                author_name = author_dict_entries['author']
                author_uri = URIRef(schema + "author/" + author_name.replace(" ", "_"))
                g.add((instance, authoredBy_uri, author_uri))
                g.add((author_uri, authored_uri, instance))

        except:
            pass
# Out:
# 21it [00:00, 4152.97it/s]

# %%
g.serialize('world-bank-kg.ttl', format='turtle', prefixes=prefixes, encoding='utf-8')
g.serialize("world-bank-kg.nt", format="nt", prefixes=prefixes, encoding='utf-8')
# Out:
# <Graph identifier=N09d496b900c14db6ba9b6254a1965296 (<class 'rdflib.graph.Graph'>)>

# %%
# Step 1: Find the URI of Brazil in your ontology
brazil_uri = "<http://schema.org/Brazil>"  # Replace with the actual URI

# Step 2: Find the most relevant documents related to Brazil
documents_query = f"""
    PREFIX schema: <http://schema.org/>
    SELECT ?document
    WHERE {{
    # ?document a/rdfs:subClassOf* schema:world_bank_document ;
        schema:countryOfOrigin {brazil_uri} .
}}
"""
qres = g.query(documents_query)
for row in qres:
    print(f"Document ID: {row.document}")
# Out:
# Document ID: http://schema.org/doc/Brazil___LATIN_AMERICA_AND
# ____________CARIBBEAN__P167455__Ceara_Rural_Sustainable_Development_and
# ____________Competitiveness_Phase_II___Procurement_Plan
# Document ID: http://schema.org/doc/Disclosable_Version_of_the_ISR__
# ____________Ceara_Rural_Sustainable_Development_and_Competitiveness
# ____________Phase_II___P167455___Sequence_No_:_11
# Document ID: http://schema.org/doc/Disclosable_Version_of_the_ISR__
# ____________Mato_Grosso_Sustainable_Development_of_Family_Farming__
# ____________P175723___Sequence_No_:_2
# Document ID: http://schema.org/doc/Disclosable_Restructuring_Paper__
# ____________Ceara_Rural_Sustainable_Development_and_Competitiveness
# ____________Phase_II___P167455
